# %% [markdown]
# Develop a two heatmaps:
# Division explorer/ matchup explorer (OR just put in league explorer)
#
# Purpose: show that some efficiencies are driven by the opponent (e.g. Radicals D) rather than the team
#
# Heatmap of various team-level indicators by matchup (ie, see conversion rates for each matchup): https://plot.ly/python/heatmaps/#heatmap-with-categorical-axis-labels
#
# First one is for a given stat, show it for every combination of teams within a division
#
# Second one is for a given matchup all efficiency stats (note - should this be in team explorer?)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from src.data.utils import load_raw_data, DATA_DIR

# %%
# Import plotly and set to work offline (ie, render plots here rather than plotly)
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
go.Heatmap?

# %%
df = pd.read_csv(f'{DATA_DIR}/processed/team_stats.csv')
df.head()
# Out:
#    year              team               opponent        date  \
# 0  2014  Chicago Wildfire  Cincinnati Revolution  2014-04-18
# 1  2014  Chicago Wildfire  Cincinnati Revolution  2014-04-26
# 2  2014  Chicago Wildfire  Cincinnati Revolution  2014-06-28
# 3  2014  Chicago Wildfire       Detroit Mechanix  2014-05-03
# 4  2014  Chicago Wildfire       Detroit Mechanix  2014-06-04
#
#                                                 game  Assists  Hockey Assists  \
# 0  Chicago Wildfire_Cincinnati Revolution_2014-04-18       22              20
# 1  Chicago Wildfire_Cincinnati Revolution_2014-04-26       27              22
# 2  Chicago Wildfire_Cincinnati Revolution_2014-06-28       21              19
# 3       Chicago Wildfire_Detroit Mechanix_2014-05-03       18              15
# 4       Chicago Wildfire_Detroit Mechanix_2014-06-04       31              22
#
#    Throws  Throwaways  Turnovers  ...  Throwaway Rate  Assist Rate  Goal Rate  \
# 0     234          17         20  ...        0.072650     0.094017   0.102804
# 1     243          23         31  ...        0.094650     0.111111   0.127358
# 2     322          18         28  ...        0.055901     0.065217   0.071429
# 3     256          30         45  ...        0.117188     0.070312   0.085308
# 4     204          17         19  ...        0.083333     0.151961   0.167568
#
#    Hold Rate  Break Rate  Scoring Efficiency  O-line Scoring Efficiency  \
# 0   0.760000    0.130435            0.511628                   0.527778
# 1   0.714286    0.607143            0.457627                   0.434783
# 2   0.923077    0.391304            0.420000                   0.545455
# 3   0.818182    0.473684            0.281250                   0.346154
# 4   0.944444    0.437500            0.620000                   0.944444
#
#    D-line Scoring Efficiency  O-line Takeaway Efficiency  \
# 0                   0.428571                      0.6875
# 1                   0.472222                      0.7500
# 2                   0.321429                      0.9000
# 3                   0.236842                      1.0000
# 4                   0.437500                         NaN
#
#    D-line Takeaway Efficiency
# 0                    0.333333
# 1                    0.804348
# 2                    0.756098
# 3                    0.812500
# 4                    0.660000
#
# [5 rows x 43 columns]

# %%
divisions = {
    'Midwest': ['Chicago Wildfire', 'Detroit Mechanix', 'Indianapolis AlleyCats', 'Minnesota Wind Chill',
               'Pittsburgh Thunderbirds', 'Madison Radicals']
}

# %%
df.team.unique()
# Out:
# array(['Chicago Wildfire', 'Cincinnati Revolution', 'DC Breeze',
#        'Detroit Mechanix', 'Indianapolis AlleyCats', 'Madison Radicals',
#        'Minnesota Wind Chill', 'Montreal Royal', 'New York Empire',
#        'Philadelphia Phoenix', 'Rochester Dragons', 'Salt Lake Lions',
#        'San Francisco FlameThrowers', 'San Jose Spiders',
#        'Seattle Raptors', 'Toronto Rush', 'Vancouver Riptide',
#        'Atlanta Hustle', 'Charlotte Express', 'Jacksonville Cannons',
#        'Los Angeles Aviators', 'Nashville NightWatch', 'Ottawa Outlaws',
#        'Pittsburgh Thunderbirds', 'Raleigh Flyers', 'San Diego Growlers',
#        'Seattle Cascades', 'Austin Sol', 'Dallas Roughnecks',
#        'Tampa Bay Cannons'], dtype=object)

# %%
indicator = 'Hold Rate'
division = 'Midwest'
teams = divisions[division]
opponents = divisions[division]
df1 = df.loc[(df.team.isin(teams)) & (df.opponent.isin(opponents))]
df1 = df1.groupby(['team', 'opponent'])[indicator].mean().reset_index()
df1.head()
# Out:
#                team                 opponent  Hold Rate
# 0  Chicago Wildfire         Detroit Mechanix   0.725623
# 1  Chicago Wildfire   Indianapolis AlleyCats   0.583925
# 2  Chicago Wildfire         Madison Radicals   0.549647
# 3  Chicago Wildfire     Minnesota Wind Chill   0.642193
# 4  Chicago Wildfire  Pittsburgh Thunderbirds   0.656191

# %%
trace = go.Heatmap(z=df1[indicator],
                   x=df1.opponent,
                   y=df1.team,
                   text=[indicator] * len(df1),
                  hoverinfo='z+text')

iplot([trace])
# Out:
# <div id="a5660e20-b38a-4a91-a7b3-10d29f76a33b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("a5660e20-b38a-4a91-a7b3-10d29f76a33b")) {
#     Plotly.newPlot("a5660e20-b38a-4a91-a7b3-10d29f76a33b", [{"hoverinfo": "z+text", "text": ["Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate"], "x": ["Detroit Mechanix", "Indianapolis AlleyCats", "Madison Radicals", "Minnesota Wind Chill", "Pittsburgh Thunderbirds", "Chicago Wildfire", "Indianapolis AlleyCats", "Madison Radicals", "Minnesota Wind Chill", "Pittsburgh Thunderbirds", "Chicago Wildfire", "Detroit Mechanix", "Madison Radicals", "Minnesota Wind Chill", "Pittsburgh Thunderbirds", "Chicago Wildfire", "Detroit Mechanix", "Indianapolis AlleyCats", "Minnesota Wind Chill", "Pittsburgh Thunderbirds", "Chicago Wildfire", "Detroit Mechanix", "Indianapolis AlleyCats", "Madison Radicals", "Pittsburgh Thunderbirds", "Chicago Wildfire", "Detroit Mechanix", "Indianapolis AlleyCats", "Madison Radicals", "Minnesota Wind Chill"], "y": ["Chicago Wildfire", "Chicago Wildfire", "Chicago Wildfire", "Chicago Wildfire", "Chicago Wildfire", "Detroit Mechanix", "Detroit Mechanix", "Detroit Mechanix", "Detroit Mechanix", "Detroit Mechanix", "Indianapolis AlleyCats", "Indianapolis AlleyCats", "Indianapolis AlleyCats", "Indianapolis AlleyCats", "Indianapolis AlleyCats", "Madison Radicals", "Madison Radicals", "Madison Radicals", "Madison Radicals", "Madison Radicals", "Minnesota Wind Chill", "Minnesota Wind Chill", "Minnesota Wind Chill", "Minnesota Wind Chill", "Minnesota Wind Chill", "Pittsburgh Thunderbirds", "Pittsburgh Thunderbirds", "Pittsburgh Thunderbirds", "Pittsburgh Thunderbirds", "Pittsburgh Thunderbirds"], "z": [0.7256228209736982, 0.5839247018083661, 0.5496470244731114, 0.6421930833857068, 0.6561909699403453, 0.5123221287531761, 0.5121557411808516, 0.35499108021248654, 0.4887276995360994, 0.5032129623314919, 0.7165538123204027, 0.7557683756587668, 0.579585657724941, 0.6304456648696066, 0.7309550840280891, 0.686601900278371, 0.8938061938061939, 0.7665965693768899, 0.7208557782087193, 0.7225758906588946, 0.6526220803491378, 0.763469734513565, 0.6639863003486848, 0.5137418613115765, 0.6059292913241745, 0.6466145845658589, 0.7423903698839761, 0.6766148898211856, 0.583602581465644, 0.6592788829609898], "type": "heatmap", "uid": "64be5e1d-a7e1-4a4d-b06c-49a99bd54893"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("a5660e20-b38a-4a91-a7b3-10d29f76a33b")) {window._Plotly.Plots.resize(document.getElementById("a5660e20-b38a-4a91-a7b3-10d29f76a33b"));};})</script>

# %% [markdown]
# # TODO - add annotations
# It seems that the native `go.Heatmap` doesn't support annotations.
# The `ff.create_annotated_heatmap` does is, but requires z to be a matrix, so I'd have to do some unwieldy reshaping

# %%
import plotly.figure_factory as ff

# %%
df1[indicator].astype('str').tolist()
# Out:
# ['0.7256228209736982',
#  '0.5839247018083661',
#  '0.5496470244731114',
#  '0.6421930833857068',
#  '0.6561909699403453',
#  '0.5123221287531761',
#  '0.5121557411808516',
#  '0.35499108021248654',
#  '0.4887276995360994',
#  '0.5032129623314919',
#  '0.7165538123204027',
#  '0.7557683756587668',
#  '0.579585657724941',
#  '0.6304456648696066',
#  '0.7309550840280891',
#  '0.686601900278371',
#  '0.8938061938061939',
#  '0.7665965693768899',
#  '0.7208557782087193',
#  '0.7225758906588946',
#  '0.6526220803491378',
#  '0.763469734513565',
#  '0.6639863003486848',
#  '0.5137418613115765',
#  '0.6059292913241745',
#  '0.6466145845658589',
#  '0.7423903698839761',
#  '0.6766148898211856',
#  '0.583602581465644',
#  '0.6592788829609898']

# %%
mat = round(df1[indicator], 2).values.reshape(len(teams) - 1,len(opponents))
mat
# Out:
# array([[0.73, 0.58, 0.55, 0.64, 0.66, 0.51],
#        [0.51, 0.35, 0.49, 0.5 , 0.72, 0.76],
#        [0.58, 0.63, 0.73, 0.69, 0.89, 0.77],
#        [0.72, 0.72, 0.65, 0.76, 0.66, 0.51],
#        [0.61, 0.65, 0.74, 0.68, 0.58, 0.66]])

# %%
fig = ff.create_annotated_heatmap(mat, x=teams)

iplot(fig)
# Out:
# <div id="57b08b4b-0261-485d-80cd-83091f3a6820" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("57b08b4b-0261-485d-80cd-83091f3a6820")) {
#     Plotly.newPlot("57b08b4b-0261-485d-80cd-83091f3a6820", [{"colorscale": "RdBu", "reversescale": false, "showscale": false, "x": ["Chicago Wildfire", "Detroit Mechanix", "Indianapolis AlleyCats", "Minnesota Wind Chill", "Pittsburgh Thunderbirds", "Madison Radicals"], "z": [[0.73, 0.58, 0.55, 0.64, 0.66, 0.51], [0.51, 0.35, 0.49, 0.5, 0.72, 0.76], [0.58, 0.63, 0.73, 0.69, 0.89, 0.77], [0.72, 0.72, 0.65, 0.76, 0.66, 0.51], [0.61, 0.65, 0.74, 0.68, 0.58, 0.66]], "type": "heatmap", "uid": "e0aa0f49-2e4a-4398-b24d-1cac908c2424"}], {"annotations": [{"font": {"color": "#000000"}, "showarrow": false, "text": "0.73", "x": "Chicago Wildfire", "xref": "x", "y": 0, "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.58", "x": "Detroit Mechanix", "xref": "x", "y": 0, "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.55", "x": "Indianapolis AlleyCats", "xref": "x", "y": 0, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.64", "x": "Minnesota Wind Chill", "xref": "x", "y": 0, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.66", "x": "Pittsburgh Thunderbirds", "xref": "x", "y": 0, "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.51", "x": "Madison Radicals", "xref": "x", "y": 0, "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.51", "x": "Chicago Wildfire", "xref": "x", "y": 1, "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.35", "x": "Detroit Mechanix", "xref": "x", "y": 1, "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.49", "x": "Indianapolis AlleyCats", "xref": "x", "y": 1, "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.5", "x": "Minnesota Wind Chill", "xref": "x", "y": 1, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.72", "x": "Pittsburgh Thunderbirds", "xref": "x", "y": 1, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.76", "x": "Madison Radicals", "xref": "x", "y": 1, "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.58", "x": "Chicago Wildfire", "xref": "x", "y": 2, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.63", "x": "Detroit Mechanix", "xref": "x", "y": 2, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.73", "x": "Indianapolis AlleyCats", "xref": "x", "y": 2, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.69", "x": "Minnesota Wind Chill", "xref": "x", "y": 2, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.89", "x": "Pittsburgh Thunderbirds", "xref": "x", "y": 2, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.77", "x": "Madison Radicals", "xref": "x", "y": 2, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.72", "x": "Chicago Wildfire", "xref": "x", "y": 3, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.72", "x": "Detroit Mechanix", "xref": "x", "y": 3, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.65", "x": "Indianapolis AlleyCats", "xref": "x", "y": 3, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.76", "x": "Minnesota Wind Chill", "xref": "x", "y": 3, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.66", "x": "Pittsburgh Thunderbirds", "xref": "x", "y": 3, "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.51", "x": "Madison Radicals", "xref": "x", "y": 3, "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0.61", "x": "Chicago Wildfire", "xref": "x", "y": 4, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.65", "x": "Detroit Mechanix", "xref": "x", "y": 4, "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "0.74", "x": "Indiana ...
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("57b08b4b-0261-485d-80cd-83091f3a6820")) {window._Plotly.Plots.resize(document.getElementById("57b08b4b-0261-485d-80cd-83091f3a6820"));};})</script>

# %% [markdown]
# ## Heatmap of multiple indicators for one team across opponents

# %%
indicators = ['Hold Rate', 'O-line Scoring Efficiency', 'D-line Scoring Efficiency', 'Break Rate']
division = 'Midwest'
team = 'Chicago Wildfire'
opponents = divisions[division]
df1 = df.loc[(df.team == team) & (df.opponent.isin(opponents))]
# df1 = df1.groupby(['team', 'opponent'])[indicators].mean().reset_index()
df1 = df1.melt(id_vars=['team', 'opponent'], value_vars=indicators, var_name='indicator')
df1.head()
# Out:
#                team                opponent  indicator     value
# 0  Chicago Wildfire        Detroit Mechanix  Hold Rate  0.818182
# 1  Chicago Wildfire        Detroit Mechanix  Hold Rate  0.944444
# 2  Chicago Wildfire        Detroit Mechanix  Hold Rate  0.600000
# 3  Chicago Wildfire  Indianapolis AlleyCats  Hold Rate  0.629630
# 4  Chicago Wildfire  Indianapolis AlleyCats  Hold Rate  0.523810

# %%
# TODO - either need to restrict to efficiency stats, or have row-level heat scale 
trace = go.Heatmap(z=df1['value'],
                   x=df1.opponent,
                   y=df1.indicator,
                   text=df1.indicator.astype('str'),
                  hoverinfo='z+text')

iplot([trace])
# Out:
# <div id="8edf9954-cf24-44a9-9850-a9abf38db303" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("8edf9954-cf24-44a9-9850-a9abf38db303")) {
#     Plotly.newPlot("8edf9954-cf24-44a9-9850-a9abf38db303", [{"hoverinfo": "z+text", "text": ["Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "Hold Rate", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "O-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency", "D-line Scoring Efficiency" ...
