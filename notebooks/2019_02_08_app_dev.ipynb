# %% [markdown]
# ## Playing around to develop app

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from src.data.utils import load_raw_data, DATA_DIR
from src.visualization.utils import palette, palette_df

# %%
df = pd.read_csv(f'{DATA_DIR}/processed/team_indicators.csv')

# %%
df.head()
# Out:
#    year              team               opponent        date  \
# 0  2014  Chicago Wildfire  Cincinnati Revolution  2014-04-18
# 1  2014  Chicago Wildfire  Cincinnati Revolution  2014-04-26
# 2  2014  Chicago Wildfire  Cincinnati Revolution  2014-06-28
# 3  2014  Chicago Wildfire       Detroit Mechanix  2014-05-03
# 4  2014  Chicago Wildfire       Detroit Mechanix  2014-06-04
#
#                                                 game  Goals  Catches    Ds  \
# 0  Chicago Wildfire_Cincinnati Revolution_2014-04-18     22    192.0   7.0
# 1  Chicago Wildfire_Cincinnati Revolution_2014-04-26     27    185.0  23.0
# 2  Chicago Wildfire_Cincinnati Revolution_2014-06-28     21    273.0  17.0
# 3       Chicago Wildfire_Detroit Mechanix_2014-05-03     18    193.0  21.0
# 4       Chicago Wildfire_Detroit Mechanix_2014-06-04     31    154.0   8.0
#
#    Turnovers  Drops  Throwaways  Goals_against
# 0       31.0    3.0        28.0             23
# 1       54.0    8.0        46.0             12
# ...

# %%
palette
# Out:
# {'Chicago Wildfire': ['#ff0000', '#40ff00'],
#  'Cincinnati Revolution': ['#ff8000', '#40ff00'],
#  'Madison Radicals': ['#fff100', '#ff00ff']}

# %%
palette_df
# Out:
#                     team   color1   color2
# 0       Chicago Wildfire  #ff0000  #40ff00
# 1  Cincinnati Revolution  #ff8000  #40ff00
# 2       Madison Radicals  #fff100  #ff00ff

# %%
pd.merge(df, palette_df, how='outer')
# Out:
#       year               team                 opponent        date  \
# 0     2014   Chicago Wildfire    Cincinnati Revolution  2014-04-18
# 1     2014   Chicago Wildfire    Cincinnati Revolution  2014-04-26
# 2     2014   Chicago Wildfire    Cincinnati Revolution  2014-06-28
# 3     2014   Chicago Wildfire         Detroit Mechanix  2014-05-03
# 4     2014   Chicago Wildfire         Detroit Mechanix  2014-06-04
# 5     2014   Chicago Wildfire         Detroit Mechanix  2014-06-07
# 6     2014   Chicago Wildfire   Indianapolis AlleyCats  2014-04-19
# 7     2014   Chicago Wildfire   Indianapolis AlleyCats  2014-05-09
# 8     2014   Chicago Wildfire         Madison Radicals  2014-05-23
# 9     2014   Chicago Wildfire         Madison Radicals  2014-05-24
# 10    2014   Chicago Wildfire         Madison Radicals  2014-06-20
# 11    2014   Chicago Wildfire     Minnesota Wind Chill  2014-04-13
# 12    2014   Chicago Wildfire     Minnesota Wind Chill  2014-05-17
# ...

# %%
df['color1'], df['color1'] = df.team.map(palette)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-3dff34890d06> in <module>
# ----> 1 df['color1'], df['color1'] = df.team.map(palette)
#
# ValueError: too many values to unpack (expected 2)

# %%
palette_df = pd.DataFrame.from_dict(palette, orient='index', columns=['color1', 'color2'])
palette_df.index.rename('team', inplace=True)
palette_df.reset_index()
# Out:
#                     team   color1   color2
# 0       Chicago Wildfire  #ff0000  #40ff00
# 1  Cincinnati Revolution  #ff8000  #40ff00
# 2       Madison Radicals  #fff100  #ff00ff

# %%
from src.visualization.utils import palette_df
palette_df
# Out:
#                     team   color1   color2
# 0       Chicago Wildfire  #ff0000  #40ff00
# 1  Cincinnati Revolution  #ff8000  #40ff00
# 2       Madison Radicals  #fff100  #ff00ff

# %%
type(palette_df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.merge(df, palette_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-6205c2007690> in <module>
# ----> 1 pd.merge(df, palette_df)
#
# c:\users\zrankin\appdata\local\continuum\miniconda3\envs\audl\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      46                          copy=copy, indicator=indicator,
#      47                          validate=validate)
# ---> 48     return op.get_result()
#      49
#      50
#
# c:\users\zrankin\appdata\local\continuum\miniconda3\envs\audl\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     544                 self.left, self.right)
#     545
# --> 546         join_index, left_indexer, right_indexer = self._get_join_info()
#     547
#     548         ldata, rdata = self.left._data, self.right._data
#
# ...

# %%
df['colors'] = df.team.map(palette)
df['color1'] = df.colors.apply(lambda x: x)

# %%
df.color1
# Out:
# 0       [#ff0000, #40ff00]
# 1       [#ff0000, #40ff00]
# 2       [#ff0000, #40ff00]
# 3       [#ff0000, #40ff00]
# 4       [#ff0000, #40ff00]
# 5       [#ff0000, #40ff00]
# 6       [#ff0000, #40ff00]
# 7       [#ff0000, #40ff00]
# 8       [#ff0000, #40ff00]
# 9       [#ff0000, #40ff00]
# 10      [#ff0000, #40ff00]
# 11      [#ff0000, #40ff00]
# 12      [#ff0000, #40ff00]
# 13      [#ff0000, #40ff00]
# 14      [#ff0000, #40ff00]
# 15      [#ff8000, #40ff00]
# 16      [#ff8000, #40ff00]
# 17      [#ff8000, #40ff00]
# 18      [#ff8000, #40ff00]
# 19      [#ff8000, #40ff00]
# 20      [#ff8000, #40ff00]
# 21      [#ff8000, #40ff00]
# 22      [#ff8000, #40ff00]
# 23      [#ff8000, #40ff00]
# 24      [#ff8000, #40ff00]
# 25      [#ff8000, #40ff00]
# 26      [#ff8000, #40ff00]
# 27      [#ff8000, #40ff00]
# 28      [#ff8000, #40ff00]
# 29                     NaN
#                ...
# 1670                   NaN
# 1671                   NaN
# 1672                   NaN
# ...

# %%
c1, c2 = df.team.map(palette)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-16a594bc57d6> in <module>
# ----> 1 c1, c2 = df.team.map(palette)
#
# ValueError: too many values to unpack (expected 2)

# %%
df['color1'] = [c[0] for c in colors]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a3524b7cd7cc> in <module>
# ----> 1 df['color1'] = [c[0] for c in colors]
#
# <ipython-input-18-a3524b7cd7cc> in <listcomp>(.0)
# ----> 1 df['color1'] = [c[0] for c in colors]
#
# TypeError: 'float' object is not subscriptable

# %%
[c for c in colors]
# Out:
# [['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff0000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  ['#ff8000', '#40ff00'],
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
colors.shape
# Out:
# (1700,)

# %%
colors[0][1]
# Out:
# '#40ff00'

# %%
df.head()
# Out:
#    year              team               opponent        date  \
# 0  2014  Chicago Wildfire  Cincinnati Revolution  2014-04-18
# 1  2014  Chicago Wildfire  Cincinnati Revolution  2014-04-26
# 2  2014  Chicago Wildfire  Cincinnati Revolution  2014-06-28
# 3  2014  Chicago Wildfire       Detroit Mechanix  2014-05-03
# 4  2014  Chicago Wildfire       Detroit Mechanix  2014-06-04
#
#                                                 game  Goals  Catches    Ds  \
# 0  Chicago Wildfire_Cincinnati Revolution_2014-04-18     22    192.0   7.0
# 1  Chicago Wildfire_Cincinnati Revolution_2014-04-26     27    185.0  23.0
# 2  Chicago Wildfire_Cincinnati Revolution_2014-06-28     21    273.0  17.0
# 3       Chicago Wildfire_Detroit Mechanix_2014-05-03     18    193.0  21.0
# 4       Chicago Wildfire_Detroit Mechanix_2014-06-04     31    154.0   8.0
#
#    Turnovers  Drops  Throwaways  Goals_against
# 0       31.0    3.0        28.0             23
# 1       54.0    8.0        46.0             12
# ...

# %%
df.team.unique()
# Out:
# array(['Chicago Wildfire', 'Cincinnati Revolution', 'DC Breeze',
#        'Detroit Mechanix', 'Indianapolis AlleyCats', 'Madison Radicals',
#        'Minnesota Wind Chill', 'Montreal Royal', 'New York Empire',
#        'Philadelphia Phoenix', 'Rochester Dragons', 'Salt Lake Lions',
#        'San Francisco FlameThrowers', 'San Jose Spiders',
#        'Seattle Raptors', 'Toronto Rush', 'Vancouver Riptide',
#        'Atlanta Hustle', 'Charlotte Express', 'Jacksonville Cannons',
#        'Los Angeles Aviators', 'Nashville NightWatch', 'Ottawa Outlaws',
#        'Pittsburgh Thunderbirds', 'Raleigh Flyers', 'San Diego Growlers',
#        'Seattle Cascades', 'Austin Sol', 'Dallas Roughnecks',
#        'Tampa Bay Cannons'], dtype=object)
